# %% [markdown]
# # ICP01 Jupyter Install
#
# ## Aravind Dudam

# %% [markdown]
# ![Aravind%20Photo.jpg](attachment:Aravind%20Photo.jpg)
#
# Hello, My name is Aravind Dudam, and I'm a graduate student at the University of South Florida working on a master's degree in business analytics and information systems. I have worked as a Design Analysis engineer for a total of four years. My daily operational activities include creating workflow pipelines and outlining new product ideas. I hope to learn more about the subjects of data science and business analytics through this course by working on more hands-on assignments that will help me build my resume and launch my career in data science, which is a field I want to work in.

# %%
# This program prints Hello world!

print('Hello world')
# Out:
# Hello world
